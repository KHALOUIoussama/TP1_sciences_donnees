# %% [markdown]
# # **Méthode 1**

# %% [markdown]
# **1(a)**

# %%
import pandas as pd
import numpy as np

# Charger les données des profils génomiques
data = pd.read_csv("data.csv")

# Charger les données des types de tumeurs
labels = pd.read_csv("labels.csv")

# Afficher les premières lignes des données pour vérification
data.head()
# Out:
#   Unnamed: 0  gene_0    gene_1    gene_2    gene_3     gene_4  gene_5  \
# 0   sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0
# 1   sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0
# 2   sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0
# 3   sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0
# 4   sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0
#
#      gene_6    gene_7  gene_8  ...  gene_20521  gene_20522  gene_20523  \
# 0  7.175175  0.591871     0.0  ...    4.926711    8.210257    9.723516
# 1  6.816049  0.000000     0.0  ...    4.593372    7.323865    9.740931
# 2  6.972130  0.452595     0.0  ...    5.125213    8.127123   10.908640
# 3  7.843375  0.434882     0.0  ...    6.076566    8.792959   10.141520
# 4  6.566967  0.360982     0.0  ...    5.996032    8.891425   10.373790
#
#    gene_20524  gene_20525  gene_20526  gene_20527  gene_20528  gene_20529  \
# ...

# %%
# Afficher les premières lignes des types de tumeurs des patients
labels.head()
# Out:
#   Unnamed: 0 Class
# 0   sample_0  PRAD
# 1   sample_1  LUAD
# 2   sample_2  PRAD
# 3   sample_3  PRAD
# 4   sample_4  BRCA

# %%
# Fusionner les données génomiques avec les étiquettes de classe en utilisant "Unnamed: 0" comme clé de fusion
merged_data = pd.merge(data, labels, on="Unnamed: 0")
merged_data
# Out:
#      Unnamed: 0  gene_0    gene_1    gene_2    gene_3     gene_4  gene_5  \
# 0      sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0
# 1      sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0
# 2      sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0
# 3      sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0
# 4      sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0
# ..          ...     ...       ...       ...       ...        ...     ...
# 796  sample_796     0.0  1.865642  2.718197  7.350099  10.006003     0.0
# 797  sample_797     0.0  3.942955  4.453807  6.346597  10.056868     0.0
# 798  sample_798     0.0  3.249582  3.707492  8.185901   9.504082     0.0
# 799  sample_799     0.0  2.590339  2.787976  7.318624   9.987136     0.0
# 800  sample_800     0.0  2.325242  3.805932  6.530246   9.560367     0.0
#
#        gene_6    gene_7  gene_8  ...  gene_20522  gene_20523  gene_20524  \
# ...

# %%
# Supprimer la colonne 'Unnamed: 0' si elle n'est pas nécessaire
merged_data = merged_data.drop(columns=['Unnamed: 0'])
merged_data
# Out:
#      gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# 0       0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# 1       0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# 2       0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# 3       0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# 4       0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
# ..      ...       ...       ...       ...        ...     ...       ...
# 796     0.0  1.865642  2.718197  7.350099  10.006003     0.0  6.764792
# 797     0.0  3.942955  4.453807  6.346597  10.056868     0.0  7.320331
# 798     0.0  3.249582  3.707492  8.185901   9.504082     0.0  7.536589
# 799     0.0  2.590339  2.787976  7.318624   9.987136     0.0  9.213464
# 800     0.0  2.325242  3.805932  6.530246   9.560367     0.0  7.957027
#
#        gene_7  gene_8  gene_9  ...  gene_20522  gene_20523  gene_20524  \
# ...

# %%
# Liste des classes de cancer
classes = merged_data['Class'].unique()

# %%
class_distances = {}

for class1 in classes:
    for class2 in classes:
        if class1 != class2:
            class1_data = merged_data[merged_data['Class'] == class1]
            class2_data = merged_data[merged_data['Class'] == class2]

            # Calculer la distance intra-classe pour class1
            intra_class_distance_class1 = np.max(np.linalg.norm(class1_data.iloc[:, 1:-1] - class1_data.iloc[:, 1:-1].mean(), axis=1))

            # Calculer la distance intra-classe pour class2
            intra_class_distance_class2 = np.max(np.linalg.norm(class2_data.iloc[:, 1:-1] - class2_data.iloc[:, 1:-1].mean(), axis=1))

            # Calculer la distance inter-classe entre class1 et class2
            inter_class_distance = np.min(np.linalg.norm(class1_data.iloc[:, 1:-1].mean() - class2_data.iloc[:, 1:-1], axis=1))

            # Calculer l'indicateur de superposition (Overlap)
            overlap = (intra_class_distance_class1 + intra_class_distance_class2) / (2 * inter_class_distance)

            print(f'Distance intra-classe entre {class1} : {intra_class_distance_class1}')
            print(f'Distance intra-classe entre {class2} : {intra_class_distance_class2}')
            print(f'Distance inter-classe entre {class1} et {class2}: {inter_class_distance}')
            print(f'Overlap entre {class1} et {class2}: {overlap}')

            # Condition pour déterminer si les classes sont bien séparées
            if overlap < 1:
                print(f'Les classes {class1} et {class2} sont bien séparées.')
            else:
                print(f'Les classes {class1} et {class2} ne sont pas bien séparées.')
            print('--------------------------------------')
# Out:
# Distance intra-classe entre PRAD : 239.573587152436
# Distance intra-classe entre LUAD : 258.41774860971384
# Distance inter-classe entre PRAD et LUAD: 224.53611026936588
# Overlap entre PRAD et LUAD: 1.108933737127476
# Les classes PRAD et LUAD ne sont pas bien séparées.
# --------------------------------------
# Distance intra-classe entre PRAD : 239.573587152436
# Distance intra-classe entre BRCA : 256.958613118049
# Distance inter-classe entre PRAD et BRCA: 197.57782458575454
# Overlap entre PRAD et BRCA: 1.2565484039302588
# Les classes PRAD et BRCA ne sont pas bien séparées.
# --------------------------------------
# Distance intra-classe entre PRAD : 239.573587152436
# Distance intra-classe entre KIRC : 270.13355136325157
# Distance inter-classe entre PRAD et KIRC: 243.94037900893616
# Overlap entre PRAD et KIRC: 1.044737120985238
# Les classes PRAD et KIRC ne sont pas bien séparées.
# --------------------------------------
# ...

# %% [markdown]
# **1(b)**

# %% [markdown]
# Distance Euclidienne

# %%
class_distances = {}

for class1 in classes:
    for class2 in classes:
        if class1 != class2:
            class1_data = merged_data[merged_data['Class'] == class1]
            class2_data = merged_data[merged_data['Class'] == class2]

            # Calculer la distance inter-classe entre class1 et class2 en utilisant la distance Euclidienne
            euclidean_distance = np.linalg.norm(class1_data.iloc[:, 1:-1].mean() - class2_data.iloc[:, 1:-1].mean())

            # Afficher le résultat
            print(f'Distance Euclidienne inter-classe entre {class1} et {class2}: {euclidean_distance}')
# Out:
# Distance Euclidienne inter-classe entre PRAD et LUAD: 189.29930752296917
# Distance Euclidienne inter-classe entre PRAD et BRCA: 169.0370988498576
# Distance Euclidienne inter-classe entre PRAD et KIRC: 233.4905710233864
# Distance Euclidienne inter-classe entre PRAD et COAD: 225.68114228151012
# Distance Euclidienne inter-classe entre LUAD et PRAD: 189.29930752296917
# Distance Euclidienne inter-classe entre LUAD et BRCA: 142.87497525348542
# Distance Euclidienne inter-classe entre LUAD et KIRC: 197.57728303137657
# Distance Euclidienne inter-classe entre LUAD et COAD: 182.02859725701836
# Distance Euclidienne inter-classe entre BRCA et PRAD: 169.0370988498576
# Distance Euclidienne inter-classe entre BRCA et LUAD: 142.87497525348542
# Distance Euclidienne inter-classe entre BRCA et KIRC: 205.41216241474152
# Distance Euclidienne inter-classe entre BRCA et COAD: 197.37561390690516
# Distance Euclidienne inter-classe entre KIRC et PRAD: 233.4905710233864
# ...

# %% [markdown]
# Distance Mahalanobis

# %%
from scipy.spatial.distance import mahalanobis

class_distances = {}

for class1 in classes:
    for class2 in classes:
        if class1 != class2:
            class1_data = merged_data[merged_data['Class'] == class1]
            class2_data = merged_data[merged_data['Class'] == class2]

            # Calculer la distance inter-classe entre class1 et class2 en utilisant la distance Mahalanobis
            mahalanobis_distance = mahalanobis(class1_data.iloc[:, 1:-1].mean(), class2_data.iloc[:, 1:-1].mean(), np.cov(data.iloc[:, 1:-1].T))

            # Afficher le résultat
            print(f'Distance Mahalanobis inter-classe entre {class1} et {class2}: {mahalanobis_distance}')
# Out:
# Distance Mahalanobis inter-classe entre PRAD et LUAD: 1738.2329124598948
# Distance Mahalanobis inter-classe entre PRAD et BRCA: 1099.4980700946774
# Distance Mahalanobis inter-classe entre PRAD et KIRC: 1882.677515079507
# Distance Mahalanobis inter-classe entre PRAD et COAD: 1910.8295228310064
# Distance Mahalanobis inter-classe entre LUAD et PRAD: 1738.2329124598948
# Distance Mahalanobis inter-classe entre LUAD et BRCA: 1355.8769025890806
# Distance Mahalanobis inter-classe entre LUAD et KIRC: 1671.0671036321244
# Distance Mahalanobis inter-classe entre LUAD et COAD: 1864.1529710094903
# Distance Mahalanobis inter-classe entre BRCA et PRAD: 1099.4980700946774
# Distance Mahalanobis inter-classe entre BRCA et LUAD: 1355.8769025890806
# Distance Mahalanobis inter-classe entre BRCA et KIRC: 1799.3342303120328
# Distance Mahalanobis inter-classe entre BRCA et COAD: 1513.6163240504832
# Distance Mahalanobis inter-classe entre KIRC et PRAD: 1882.677515079507
# ...

# %% [markdown]
# Distance Cosinus

# %%
from sklearn.metrics.pairwise import cosine_distances

class_distances = {}

for class1 in classes:
    for class2 in classes:
        if class1 != class2:
            class1_data = merged_data[merged_data['Class'] == class1]
            class2_data = merged_data[merged_data['Class'] == class2]

            # Calculer la distance inter-classe entre class1 et class2 en utilisant la distance cosinus
            cosine_distance = cosine_distances([class1_data.iloc[:, 1:-1].mean()], [class2_data.iloc[:, 1:-1].mean()])[0][0]

            # Afficher le résultat
            print(f'Distance Cosinus inter-classe entre {class1} et {class2}: {cosine_distance}')
# Out:
# Distance Cosinus inter-classe entre PRAD et LUAD: 0.015203202789398906
# Distance Cosinus inter-classe entre PRAD et BRCA: 0.012212398607942099
# Distance Cosinus inter-classe entre PRAD et KIRC: 0.023137643968227928
# Distance Cosinus inter-classe entre PRAD et COAD: 0.02187282853940098
# Distance Cosinus inter-classe entre LUAD et PRAD: 0.015203202789398906
# Distance Cosinus inter-classe entre LUAD et BRCA: 0.00867988285157173
# Distance Cosinus inter-classe entre LUAD et KIRC: 0.016530901151978084
# Distance Cosinus inter-classe entre LUAD et COAD: 0.014124682754792062
# Distance Cosinus inter-classe entre BRCA et PRAD: 0.012212398607942099
# Distance Cosinus inter-classe entre BRCA et LUAD: 0.00867988285157173
# Distance Cosinus inter-classe entre BRCA et KIRC: 0.01799192518499637
# Distance Cosinus inter-classe entre BRCA et COAD: 0.016895012038556922
# Distance Cosinus inter-classe entre KIRC et PRAD: 0.023137643968227928
# ...

# %% [markdown]
# # **Méthode 2**
